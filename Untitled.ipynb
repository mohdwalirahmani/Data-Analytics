# %%
import json

# %%
def load_dataset(filename):
    with open (filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_dataset("Product_dataset.json")
print(data)
print(type(data))
# Out:
# {'store': 'TechBazaar', 'products': [{'product_id': 101, 'name': 'Wireless Earbuds', 'price': 1999, 'in_stock': True, 'ratings': [4, 5, 4, 5]}, {'product_id': 102, 'name': 'Laptop Stand', 'price': 899, 'in_stock': True, 'ratings': [5, 5, 4]}, {'product_id': 103, 'name': 'Mechanical Keyboard', 'price': 4499, 'in_stock': False, 'ratings': [4, 4, 5, 5, 4]}]}
# <class 'dict'>
